# %%
# %matplotlib inline
# %matplotlib notebook  　
import numpy as np
from pandas import *
from pylab import *
import matplotlib.pyplot as plt

plt.rcParams['font.family'] ='sans-serif'#使用するフォント
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['xtick.major.width'] = 1.0#x軸主目盛り線の線幅
plt.rcParams['ytick.major.width'] = 1.0#y軸主目盛り線の線幅
plt.rcParams['font.size'] = 6 #フォントの大きさ
plt.rcParams['axes.linewidth'] = 1.0# 軸の線幅edge linewidth。囲みの太さ

# %% [markdown]
# ### SSD  Loss

# %%
ssd_train = read_csv('../../data/run_.-tag-loss.csv')
ssd_val = read_csv('../../data/run_.-tag-val_loss.csv')

# %%
ax = plt.gca()
plt.plot(ssd_train['Step'], ssd_train['Value'], label='training loss')
plt.plot(ssd_val['Step'], ssd_val['Value'], label='validation loss')
plt.ylim(0.0) 
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
plt.legend(bbox_to_anchor=(1, 1), loc=0, borderaxespad=0.)
ax.grid()

# %%
plt.savefig('ssd_loss.pdf',transparent=True)

# %% [markdown]
# ## SSD-RGBD-1

# %%
rgbd1_train = read_csv('../../data/SSD-RGBD1_train.csv')
rgbd1_val = read_csv('../../data/SSD-RGBD1_val.csv')
rgbd1_train = rgbd1_train[:100]
rgbd1_val = rgbd1_val[:100]

# %%
ax = plt.gca()
plt.plot(rgbd1_train['Step'], rgbd1_train['Value'], label='RGBD A train loss')
plt.plot(rgbd1_val['Step'], rgbd1_val['Value'], label='RGBD A val loss')
plt.plot(ssd_train['Step'], ssd_train['Value'], label='SSD train loss')
plt.plot(ssd_val['Step'], ssd_val['Value'], label='SSD val loss')
plt.ylim(0.0) 
plt.xlabel('Epoch')
plt.ylabel('Loss')
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
plt.legend(bbox_to_anchor=(1, 1), loc=0, borderaxespad=0.)
ax.grid()
plt.savefig('ssd_rgbdA.png', transparent=True)

# %%
plt.savefig('ssd_rgbdA.png', transparent=True)

# %%
rgbd1_train = read_csv('../../data/RGBD-1_v1_train.csv')
rgbd1_val = read_csv('../../data/RGBD-1_v1_val.csv')
rgbd2_train = read_csv('../../data/RGBD-2_v1_train.csv')
rgbd2_val = read_csv('../../data/RGBD-2_v1_val.csv')
rgbd3_train = read_csv('../../data/RGBD-3_v1_train.csv')
rgbd3_val = read_csv('../../data/RGBD-3_v1_val.csv')
rgbd1_train = rgbd1_train[:100]
rgbd1_val = rgbd1_val[:100]
rgbd2_train = rgbd2_train[:100]
rgbd2_val = rgbd2_val[:100]
rgbd3_train = rgbd3_train[:100]
rgbd3_val = rgbd3_val[:100]

# %%
ax = plt.gca()
plt.plot(rgbd2_train['Step'], rgbd2_train['Value'], label='Model A train loss')
plt.plot(rgbd2_val['Step'], rgbd2_val['Value'], label='Model A val loss')
plt.plot(rgbd3_train['Step'], rgbd3_train['Value'], label='Model B train loss')
plt.plot(rgbd3_val['Step'], rgbd3_val['Value'], label='Model B val loss')
plt.plot(rgbd1_train['Step'], rgbd1_train['Value'], label='Model  C train loss')
plt.plot(rgbd1_val['Step'], rgbd1_val['Value'], label='Model C val loss')
plt.plot(ssd_train['Step'], ssd_train['Value'], label='SSD train loss')
plt.plot(ssd_val['Step'], ssd_val['Value'], label='SSD val loss')
plt.ylim(1.0) 
plt.xlabel('Epoch')
plt.ylabel('Loss')
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
plt.legend(bbox_to_anchor=(1, 1), loc=0, borderaxespad=0.)
ax.grid()
plt.savefig('loss_plot.png', transparent=True)

# %%
ax = plt.gca()
plt.plot(rgbd2_train['Step'], rgbd2_train['Value'], label='Model A train loss')
plt.plot(rgbd3_train['Step'], rgbd3_train['Value'], label='Model B train loss')
plt.plot(rgbd1_train['Step'], rgbd1_train['Value'], label='Model  C train loss')
plt.plot(ssd_train['Step'], ssd_train['Value'], label='SSD train loss')
plt.ylim(1.0) 
plt.xlabel('Epoch')
plt.ylabel('Loss')
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
plt.legend(bbox_to_anchor=(1, 1), loc=0, borderaxespad=0.)
ax.grid()
plt.savefig('train_loss_plot.png', transparent=True)

# %%
ax = plt.gca()
plt.plot(rgbd2_val['Step'], rgbd2_val['Value'], label='Model A val loss')
plt.plot(rgbd3_val['Step'], rgbd3_val['Value'], label='Model B val loss')
plt.plot(rgbd1_val['Step'], rgbd1_val['Value'], label='Model C val loss')
plt.plot(ssd_val['Step'], ssd_val['Value'], label='SSD val loss')
plt.ylim(2.0) 
plt.xlabel('Epoch')
plt.ylabel('Loss')
ax.yaxis.set_major_formatter(plt.FormatStrFormatter('%.2f'))
plt.legend(bbox_to_anchor=(1, 1), loc=0, borderaxespad=0.)
ax.grid()
plt.savefig('val_loss_plot.png', transparent=True)
